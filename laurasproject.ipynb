# %%
import pandas as pd #reading csv files
import numpy as np #linear algebra and math
import matplotlib.pyplot as plt # plotting
import seaborn as sns 
import re
import sklearn
import os
# %matplotlib inline

# %%
df = pd.read_sas('demographic_nhanes.XPT')

# %%
df
# Out:
#          SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0     83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1     83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2     83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3     83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4     83736.0       9.0       2.0       2.0      42.0       NaN       4.0
# 5     83737.0       9.0       2.0       2.0      72.0       NaN       1.0
# 6     83738.0       9.0       2.0       2.0      11.0       NaN       1.0
# 7     83739.0       9.0       2.0       1.0       4.0       NaN       3.0
# 8     83740.0       9.0       2.0       1.0       1.0      13.0       2.0
# 9     83741.0       9.0       2.0       1.0      22.0       NaN       4.0
# 10    83742.0       9.0       2.0       2.0      32.0       NaN       1.0
# 11    83743.0       9.0       2.0       1.0      18.0       NaN       5.0
# ...

# %%
df2 = pd.read_sas("alcohol_nhanes.XPT")

# %%
df2
# Out:
#          SEQN  ALQ101  ALQ110       ALQ120Q  ALQ120U  ALQ130       ALQ141Q  \
# 0     83732.0     1.0     NaN  1.000000e+00      2.0     1.0  5.397605e-79
# 1     83733.0     1.0     NaN  7.000000e+00      1.0     6.0  7.000000e+00
# 2     83734.0     1.0     NaN  5.397605e-79      NaN     NaN           NaN
# 3     83735.0     2.0     1.0  3.000000e+00      3.0     1.0  5.397605e-79
# 4     83736.0     2.0     1.0  1.000000e+00      3.0     1.0  5.397605e-79
# 5     83737.0     2.0     2.0           NaN      NaN     NaN           NaN
# 6     83741.0     1.0     NaN  3.000000e+00      2.0     8.0  2.000000e+01
# 7     83742.0     1.0     NaN  1.000000e+00      2.0     1.0  5.397605e-79
# 8     83743.0     NaN     NaN           NaN      NaN     NaN           NaN
# 9     83744.0     1.0     NaN  5.397605e-79      NaN     NaN           NaN
# 10    83747.0     1.0     NaN  6.000000e+00      1.0     1.0  5.397605e-79
# ...

# %%
files = os.listdir('data')

# %%
d = {}

for file in files:
    df = pd.read_sas('data/' + file)
    
    name = file.strip('.XPT')
    d[name] = df

# %%
d['demographic_nhanes'].INDHHIN2 #total annual household income in dollar ranges
# Out:
# 0       10.0
# 1        4.0
# 2        5.0
# 3       10.0
# 4        7.0
# 5       14.0
# 6        6.0
# 7       15.0
# 8       77.0
# 9        7.0
# 10       6.0
# 11      15.0
# 12       3.0
# 13       4.0
# 14      12.0
# 15       3.0
# 16       6.0
# 17      14.0
# 18      10.0
# 19       4.0
# 20      15.0
# 21       8.0
# 22       6.0
# 23       5.0
# 24       7.0
# 25       5.0
# 26       9.0
# 27       7.0
# 28       7.0
# 29       1.0
#         ...
# 9941     2.0
# 9942    15.0
# 9943    15.0
# 9944     7.0
# 9945    12.0
# 9946     7.0
# 9947     9.0
# 9948    13.0
# 9949     6.0
# 9950    15.0
# 9951     6.0
# 9952    14.0
# 9953     3.0
# 9954     8.0
# 9955     2.0
# 9956    99.0
# 9957     3.0
# 9958    15.0
# 9959    10.0
# 9960    15.0
# 9961     5.0
# 9962     3.0
# 9963     4.0
# 9964     9.0
# 9965     7.0
# 9966     6.0
# 9967    15.0
# 9968     1.0
# 9969    15.0
# 9970    10.0
# Name: INDHHIN2, Length: 9971, dtype: float64

# %%
d['druguse_nhanes']
# Out:
#          SEQN  DUQ200  DUQ210  DUQ211  DUQ213       DUQ215Q  DUQ215U  DUQ217  \
# 0     83732.0     NaN     NaN     NaN     NaN           NaN      NaN     NaN
# 1     83733.0     2.0     NaN     NaN     NaN           NaN      NaN     NaN
# 2     83735.0     2.0     NaN     NaN     NaN           NaN      NaN     NaN
# 3     83736.0     1.0    25.0     1.0    25.0  5.397605e-79      1.0     5.0
# 4     83741.0     1.0    15.0     1.0    16.0  1.000000e+00      4.0     4.0
# 5     83742.0     1.0    18.0     2.0     NaN           NaN      NaN     NaN
# 6     83743.0     2.0     NaN     NaN     NaN           NaN      NaN     NaN
# 7     83744.0     1.0    18.0     2.0     NaN           NaN      NaN     NaN
# 8     83747.0     2.0     NaN     NaN     NaN           NaN      NaN     NaN
# 9     83750.0     1.0    21.0     2.0     NaN           NaN      NaN     NaN
# 10    83752.0     1.0    14.0     2.0     NaN           NaN      NaN     NaN
# ...
